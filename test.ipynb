# %%
from scipy.io import loadmat
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.fft import ifft, fft, fftfreq, fftshift, ifft2, fft2
from scipy import signal
from scipy.signal import spectrogram
from scipy.io import loadmat, wavfile
from scipy.interpolate import interp2d
from scipy.interpolate import RectBivariateSpline

from Klyazma2024 import get_audio, spec_plot, full_process, build_spec, t_plot

# %%
NFFT = 5000
upper_edge = 5000
pathx = 'TASCAM_Files/TASCAM_0035S1.wav'
pathy = 'TASCAM_Files/TASCAM_0035S2.wav'
pathz = 'TASCAM_Files/TASCAM_0035S3.wav'
T_beg = [931.75, 960.9, 988.6, 1019.3, 1049.7, 1079.9, 1110.1, 1140.8]
T_end = [932.3, 961.4, 989.3, 1020.0, 1050.3, 1080.5, 1110.7, 1141.5]

data = {'freq': [], 't': [], 'sxx': []}

# %%
f, t, sxx = full_process(pathx, T_beg[0], T_end[0], NFFT)
data['freq'] = f

# %%
for i in range(len(T_beg)):
    print(f'Удар {i+1}')
    print('Канал Х')
    t_plot(pathx, T_beg[i], T_end[i])
    print('Kaнал У')
    t_plot(pathz, T_beg[i], T_end[i])
    print('Kaнал Z')
    t_plot(pathy, T_beg[i], T_end[i])
    
# for i in range(len(T_beg)):
#     print(f'Удар {i+1} по каналу Z')
#     t_plot(pathz, T_beg[i], T_end[i])
    
# for i in range(len(T_beg)):
#     print(f'Удар {i+1} по каналу Y')
#     t_plot(pathy, T_beg[i], T_end[i])
# Out:
# Удар 1
# Канал Х
# Kaнал У
# Kaнал Z
# Удар 2
# Канал Х
# Kaнал У
# Kaнал Z
# Удар 3
# Канал Х
# Kaнал У
# Kaнал Z
# Удар 4
# Канал Х
# Kaнал У
# Kaнал Z
# Удар 5
# Канал Х
# Kaнал У
# Kaнал Z
# Удар 6
# Канал Х
# Kaнал У
# Kaнал Z
# Удар 7
# Канал Х
# Kaнал У
# Kaнал Z
# Удар 8
# Канал Х
# Kaнал У
# Kaнал Z

# %%
for i in range(len(T_beg)):
    print(f'Удар {i+1}')
    f, tx, sxxx = full_process(pathx, T_beg[i], T_end[i], NFFT)
    f, ty, sxxy = full_process(pathz, T_beg[i], T_end[i], NFFT)
    f, tz, sxxz = full_process(pathy, T_beg[i], T_end[i], NFFT)
    data['t'].append(tx)
    data['t'].append(ty)
    data['t'].append(tz)
    data['sxx'].append(sxxx)
    data['sxx'].append(sxxy)
    data['sxx'].append(sxxz)
    print('X')
    build_spec(f, tx, sxxx)
    print('Y')
    build_spec(f, ty, sxxy)
    print('Z')
    build_spec(f, tz, sxxz)

# for i in range(len(T_beg)):
#     print(f'Удар {i+1} по каналу Y')
#     f, t, sxx = full_process(pathz, T_beg[i], T_end[i], NFFT)
#     data['t'].append(t)
#     data['sxx'].append(sxx)
#     build_spec(f, t, sxx)

# for i in range(len(T_beg)):
#     print(f'Удар {i+1} по каналу Z')
#     f, t, sxx = full_process(pathy, T_beg[i], T_end[i], NFFT)
#     data['t'].append(t)
#     data['sxx'].append(sxx)
#     build_spec(f, t, sxx)
# Out:
# Удар 1
# X
# Y
# Z
# Удар 2
# X
# Y
# Z
# Удар 3
# X
# Y
# Z
# Удар 4
# X
# Y
# Z
# Удар 5
# X
# Y
# Z
# Удар 6
# X
# Y
# Z
# Удар 7
# X
# Y
# Z
# Удар 8
# X
# Y
# Z

# %%
data['freq']
# Out:
# array([0.000000e+00, 8.820000e+00, 1.764000e+01, ..., 2.203236e+04,
#        2.204118e+04, 2.205000e+04])

# %% [markdown]
# фильтр 250 гц
