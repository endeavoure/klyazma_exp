# %%
from scipy.io import loadmat
import matplotlib.pyplot as plt
import numpy as np
from scipy.fft import ifft, fft, fftfreq, fftshift, ifft2, fft2
from scipy import signal
from scipy.signal import spectrogram
from scipy.io import loadmat, wavfile
from scipy.interpolate import interp2d
from scipy.interpolate import RectBivariateSpline

from Klyazma2024 import get_audio, spec_plot, full_process

# %%
NFFT = 5000
path = '/Users/alexanderknyshov/Desktop/exp/PY/TASCAM_0035S1.wav'
T_beg = [931.75, 960.9, 988.6, 1019.3, 1049.7, 1079.9, 1110.1, 1140.8]
T_end = [932.3, 960.4, 989.3, 1020.0, 1050.3, 1080.5, 1110.7, 1142.0]

# %%
f, t, sxx = full_process(path, T_beg[0], T_end[0], NFFT)
